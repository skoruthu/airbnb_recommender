# %%
import pandas as pd
import seaborn as sns
import numpy as np
import warnings

from matplotlib import pyplot as plt

# %%
df=pd.read_csv('data/listings.csv.gz')

# %% [markdown]
# ## Df Shape

# %%
print('Df Dimensions:',df.shape)
# Out:
# Df Dimensions: (66641, 74)

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# ## Missing values

# %%
missing_df=pd.DataFrame(df.isnull().sum(),columns=['missing rows'])
criteria=(missing_df['missing rows']!=0)
missing_df=missing_df[criteria].reset_index()

# %%
plt.figure(figsize=(20,10))
ax = sns.barplot(x="missing rows", y="index",data=missing_df)

# %%
print('Rows with at least 1 missing column val:',df.isnull().any(axis = 1).sum())
# Out:
# Rows with at least 1 missing column val: 66641

# %%
missing_df
# Out:
#                            index  missing rows
# 0                           name            24
# 1                    description          2344
# 2          neighborhood_overview         26674
# 3                      host_name            59
# 4                     host_since            59
# 5                  host_location           201
# 6                     host_about         29692
# 7             host_response_time         34334
# 8             host_response_rate         34334
# 9           host_acceptance_rate         32993
# 10             host_is_superhost            59
# 11            host_thumbnail_url            59
# 12              host_picture_url            59
# 13            host_neighbourhood         19521
# 14           host_listings_count            59
# 15     host_total_listings_count            59
# 16          host_has_profile_pic            59
# 17        host_identity_verified            59
# 18                 neighbourhood         26673
# 19  neighbourhood_group_cleansed         66641
# 20                     bathrooms         66641
# 21                bathrooms_text           244
# 22                      bedrooms          4017
# 23                          beds          3646
# 24        minimum_minimum_nights             3
# 25        maximum_minimum_nights             3
# 26        minimum_maximum_nights             3
# 27        maximum_maximum_nights             3
# 28        minimum_nights_avg_ntm             3
# 29        maximum_nights_avg_ntm             3
# 30              calendar_updated         66641
# 31                  first_review         18559
# 32                   last_review         18559
# 33          review_scores_rating         18559
# 34        review_scores_accuracy         19877
# 35     review_scores_cleanliness         19866
# 36         review_scores_checkin         19916
# 37   review_scores_communication         19880
# 38        review_scores_location         19917
# 39           review_scores_value         19920
# 40                       license         66641
# 41             reviews_per_month         18559

# %% [markdown]
# ## Properties per host

# %%
listings=pd.DataFrame(df.groupby(['host_id'])['host_id'].count())
listings.columns=['listings']
listings.describe()
# Out:
#            listings
# count  44695.000000
# mean       1.491017
# std        5.949452
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max      845.000000

# %%
percentiles=[0.80,0.85,0.90,0.95]
prop=[]

for p in percentiles:
   prop.append(df.host_id.value_counts().quantile(p))
print(pd.DataFrame({'percentile':percentiles,'listings':prop}))
# Out:
#    percentile  listings
# 0        0.80       1.0
# 1        0.85       2.0
# 2        0.90       2.0
# 3        0.95       3.0

# %%
listings['ctr']=''
listings['ctr']=listings['listings'].apply(lambda x: '>=3' if x>=3 else x)
listings=pd.DataFrame(listings.ctr.value_counts())
listings=listings.reset_index()
listings.columns=['host with n properties','count']

# %%
listings
# Out:
#   host with n properties  count
# 0                      1  37505
# 1                      2   4454
# 2                    >=3   2736

# %%
ax = sns.barplot(x="host with n properties", y="count", data=listings)
plt.title('Countplot of Host w/ n properties')
# Out:
# Text(0.5, 1.0, 'Countplot of Host w/ n properties')

# %% [markdown]
# ## Columns with Extreme Outliers

# %%
num_cols = list(df.select_dtypes(include=np.number).columns)
drop_cols= ['id','scrape_id','host_id','license']
cols=[]

for i in num_cols:
    if i not in drop_cols:
        cols.append(i)
df[cols].describe().T
# Out:
#                                                 count           mean  \
# host_listings_count                           66582.0      64.943213
# host_total_listings_count                     66582.0      64.943213
# neighbourhood_group_cleansed                      0.0            NaN
# latitude                                      66641.0      51.509631
# longitude                                     66641.0      -0.127954
# accommodates                                  66641.0       3.004937
# bathrooms                                         0.0            NaN
# bedrooms                                      62624.0       1.489253
# beds                                          62995.0       1.757981
# minimum_nights                                66641.0       6.654852
# maximum_nights                                66641.0   23817.138503
# minimum_minimum_nights                        66638.0       7.435997
# maximum_minimum_nights                        66638.0      11.029398
# minimum_maximum_nights                        66638.0  346176.135673
# maximum_maximum_nights                        66638.0  829579.131231
# minimum_nights_avg_ntm                        66638.0       8.837165
# maximum_nights_avg_ntm                        66638.0  778756.348544
# calendar_updated                                  0.0            NaN
# availability_30                               66641.0       6.391126
# availability_60                               66641.0      16.046353
# availability_90                               66641.0      26.662535
# availability_365                              66641.0      99.679807
# number_of_reviews                             66641.0      15.651086
# number_of_reviews_ltm                         66641.0       2.078915
# number_of_reviews_l30d                        66641.0       0.287511
# review_scores_rating                          48082.0       4.540116
# review_scores_accuracy                        46764.0       4.733359
# review_scores_cleanliness                     46775.0       4.622239
# review_scores_checkin                         46725.0       4.792929
# review_scores_communication                   46761.0       4.807941
# review_scores_location                        46724.0       4.748040
# review_scores_value                           46721.0       4.636002
# calculated_host_listings_count                66641.0      25.229979
# calculated_host_listings_count_entire_homes   66641.0      20.727120
# calculated_host_listings_count_private_rooms  66641.0       4.225057
# calculated_host_listings_count_shared_rooms   66641.0       0.212107
# reviews_per_month                             48082.0       0.635780
#
#                                                        std        min  \
# host_listings_count                           3.765785e+02   0.000000
# host_total_listings_count                     3.765785e+02   0.000000
# neighbourhood_group_cleansed                           NaN        NaN
# latitude                                      4.833392e-02  51.295937
# longitude                                     9.731470e-02  -0.496160
# accommodates                                  1.927051e+00   0.000000
# bathrooms                                              NaN        NaN
# bedrooms                                      8.839426e-01   1.000000
# beds                                          1.262523e+00   1.000000
# minimum_nights                                3.039370e+01   1.000000
# maximum_nights                                4.375146e+06   1.000000
# minimum_minimum_nights                        3.329141e+01   1.000000
# maximum_minimum_nights                        4.502954e+01   1.000000
# minimum_maximum_nights                        2.666617e+07   1.000000
# maximum_maximum_nights                        4.181635e+07   1.000000
# minimum_nights_avg_ntm                        3.756989e+01   1.000000
# maximum_nights_avg_ntm                        4.016585e+07   1.000000
# calendar_updated                                       NaN        NaN
# availability_30                               9.993942e+00   0.000000
# availability_60                               2.192971e+01   0.000000
# availability_90                               3.459493e+01   0.000000
# availability_365                              1.342400e+02   0.000000
# number_of_reviews                             3.677723e+01   0.000000
# number_of_reviews_ltm                         7.466038e+00   0.000000
# number_of_reviews_l30d                        1.076328e+00   0.000000
# review_scores_rating                          9.138128e-01   0.000000
# review_scores_accuracy                        5.099024e-01   0.000000
# review_scores_cleanliness                     5.844383e-01   0.000000
# review_scores_checkin                         4.735040e-01   0.000000
# review_scores_communication                   4.680917e-01   0.000000
# review_scores_location                        4.260474e-01   0.000000
# review_scores_value                           5.214623e-01   0.000000
# calculated_host_listings_count                1.091862e+02   1.000000
# calculated_host_listings_count_entire_homes   1.017558e+02   0.000000
# calculated_host_listings_count_private_rooms  2.091827e+01   0.000000
# calculated_host_listings_count_shared_rooms   3.240567e+00   0.000000
# reviews_per_month                             1.037195e+00   0.010000
#
#                                                    25%         50%  \
# host_listings_count                            1.00000     1.00000
# host_total_listings_count                      1.00000     1.00000
# neighbourhood_group_cleansed                       NaN         NaN
# latitude                                      51.48287    51.51383
# longitude                                     -0.18867    -0.12493
# accommodates                                   2.00000     2.00000
# bathrooms                                          NaN         NaN
# bedrooms                                       1.00000     1.00000
# beds                                           1.00000     1.00000
# minimum_nights                                 1.00000     2.00000
# maximum_nights                                31.00000  1125.00000
# minimum_minimum_nights                         1.00000     2.00000
# maximum_minimum_nights                         2.00000     3.00000
# minimum_maximum_nights                        65.00000  1125.00000
# maximum_maximum_nights                        90.00000  1125.00000
# minimum_nights_avg_ntm                         1.00000     2.40000
# maximum_nights_avg_ntm                        90.00000  1125.00000
# calendar_updated                                   NaN         NaN
# availability_30                                0.00000     0.00000
# availability_60                                0.00000     0.00000
# availability_90                                0.00000     0.00000
# availability_365                               0.00000     2.00000
# number_of_reviews                              0.00000     3.00000
# number_of_reviews_ltm                          0.00000     0.00000
# number_of_reviews_l30d                         0.00000     0.00000
# review_scores_rating                           4.50000     4.81000
# review_scores_accuracy                         4.67000     4.90000
# review_scores_cleanliness                      4.50000     4.82000
# review_scores_checkin                          4.78000     4.96000
# review_scores_communication                    4.81000     5.00000
# review_scores_location                         4.67000     4.88000
# review_scores_value                            4.50000     4.77000
# calculated_host_listings_count                 1.00000     1.00000
# calculated_host_listings_count_entire_homes    0.00000     1.00000
# calculated_host_listings_count_private_rooms   0.00000     1.00000
# calculated_host_listings_count_shared_rooms    0.00000     0.00000
# reviews_per_month                              0.09000     0.29000
#
#                                                      75%           max
# host_listings_count                              3.00000  3.750000e+03
# host_total_listings_count                        3.00000  3.750000e+03
# neighbourhood_group_cleansed                         NaN           NaN
# latitude                                        51.53996  5.167983e+01
# longitude                                       -0.06896  2.885700e-01
# accommodates                                     4.00000  1.600000e+01
# bathrooms                                            NaN           NaN
# bedrooms                                         2.00000  2.200000e+01
# beds                                             2.00000  3.800000e+01
# minimum_nights                                   4.00000  1.125000e+03
# maximum_nights                                1125.00000  1.000000e+09
# minimum_minimum_nights                           4.00000  1.125000e+03
# maximum_minimum_nights                           5.00000  1.125000e+03
# minimum_maximum_nights                        1125.00000  2.147484e+09
# maximum_maximum_nights                        1125.00000  2.147484e+09
# minimum_nights_avg_ntm                           5.00000  1.125000e+03
# maximum_nights_avg_ntm                        1125.00000  2.147484e+09
# calendar_updated                                     NaN           NaN
# availability_30                                 10.00000  3.000000e+01
# availability_60                                 35.00000  6.000000e+01
# availability_90                                 63.00000  9.000000e+01
# availability_365                               180.00000  3.650000e+02
# number_of_reviews                               14.00000  9.740000e+02
# number_of_reviews_ltm                            1.00000  5.160000e+02
# number_of_reviews_l30d                           0.00000  8.500000e+01
# review_scores_rating                             5.00000  5.000000e+00
# review_scores_accuracy                           5.00000  5.000000e+00
# review_scores_cleanliness                        5.00000  5.000000e+00
# review_scores_checkin                            5.00000  5.000000e+00
# review_scores_communication                      5.00000  5.000000e+00
# review_scores_location                           5.00000  5.000000e+00
# review_scores_value                              5.00000  5.000000e+00
# calculated_host_listings_count                   3.00000  8.450000e+02
# calculated_host_listings_count_entire_homes      1.00000  8.440000e+02
# calculated_host_listings_count_private_rooms     1.00000  1.880000e+02
# calculated_host_listings_count_shared_rooms      0.00000  5.600000e+01
# reviews_per_month                                0.79000  5.766000e+01

# %%
cols=['bedrooms','minimum_nights','maximum_nights','availability_30','availability_60','availability_365',
     'review_scores_rating','reviews_per_month']

nums=df[cols]
fig, ax = plt.subplots(2,4,figsize=(18,7))
col = 0
for axes in ax.flat:
    sns.boxplot(x=nums[cols[col]], ax=axes)
    col +=1
plt.suptitle('Distribution for possibly skewed variables')
plt.show()

# %% [markdown]
# ## Inactive Listings

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
from dateutil import parser
host_age=list(df.host_since)
host_age = [i for i in host_age if str(i) != 'nan']


host_age = [parser.parse(str(i)).date() for i in host_age ]
print('Earliest listing date:',min(host_age))
print('Latest listing date:',max(host_age))
# Out:
# Earliest listing date: 2008-08-14
# Latest listing date: 2021-12-06

# %%
criteria1=(df.host_since<='2020-12-05')
criteria2=(df.host_since>'2020-12-05')
df_exp=df[criteria1]
df_exp['old_new']='old'
df_new=df[criteria2]
df_new['old_new']='new'

df_combined=pd.concat([df_new,df_exp])
counts=pd.DataFrame(df_combined['old_new'].value_counts()).reset_index()
counts.columns=['type','freq']
sns.barplot(x='type',y='freq',data=counts)
plt.title('New, Old Listing Counts')
plt.show()
print(counts)
# Out:
# <ipython-input-19-eeacc315290e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_exp['old_new']='old'
# <ipython-input-19-eeacc315290e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['old_new']='new'
#   type   freq
# 0  old  64338
# 1  new   2244

# %%
df_exp['reviews_per_month'].describe()
# Out:
# count    46719.000000
# mean         0.604881
# std          0.933300
# min          0.010000
# 25%          0.080000
# 50%          0.280000
# 75%          0.750000
# max         28.400000
# Name: reviews_per_month, dtype: float64
