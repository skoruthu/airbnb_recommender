# %%
#Import Packages
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer

# %%
#Import CSV
listing = pd.read_csv("data/listings.csv")
listing_exp = pd.read_csv("data/listings_exp.csv")
#calendar = pd.read_csv("data/calendar.csv")
neighbour = pd.read_csv("data/neighbourhoods.csv")
review = pd.read_csv("data/reviews.csv")
review_exp = pd.read_csv("data/reviews_exp.csv")

# %%
#Split and establish new columns to store comments length
review_exp['comments_len'] = review_exp['comments'].str.split().str.len()

# %%
#Exclude comments in different language or those with less than 5 words
review_exp = review_exp.loc[review_exp['comments_len'] > 5]

# %%
#Remove duplicates, if any
review_exp = review_exp.drop_duplicates(subset = ['id', 'listing_id', 'reviewer_id', 'comments_len'])

# %%
#Find out average # of reviews done by reviewers
#Average seems to be 1.16, so that means those that post more than 2 are key reviewers
review_exp.groupby(by=['reviewer_id']).count().sort_values(by='listing_id', ascending=False).describe()
# Out:
#           listing_id             id           date  reviewer_name  \
# count  832653.000000  832653.000000  832653.000000  832653.000000
# mean        1.163690       1.163690       1.163690       1.163690
# std         0.755315       0.755315       0.755315       0.755315
# min         1.000000       1.000000       1.000000       1.000000
# 25%         1.000000       1.000000       1.000000       1.000000
# 50%         1.000000       1.000000       1.000000       1.000000
# 75%         1.000000       1.000000       1.000000       1.000000
# max        92.000000      92.000000      92.000000      92.000000
#
#             comments   comments_len
# count  832653.000000  832653.000000
# mean        1.163690       1.163690
# std         0.755315       0.755315
# min         1.000000       1.000000
# 25%         1.000000       1.000000
# 50%         1.000000       1.000000
# 75%         1.000000       1.000000
# max        92.000000      92.000000

# %%
#Group by reviewers and get those that have reviewed more than 2 times as an array
review_grouped = review_exp.groupby(by=['reviewer_id']).count().sort_values(by='listing_id', ascending=False)
key_reviewer = review_grouped[review_grouped['listing_id'] > 2].reset_index()['reviewer_id'].values

# %%
#Establish a new column with key reviewer value
review_exp['key_reviewer'] = np.where(review_exp['reviewer_id'].isin(key_reviewer), 1, 0)

# %%
review_exp
# Out:
#          listing_id                  id        date  reviewer_id  \
# 0             13913               80770  2010-08-18       177109
# 1             13913              367568  2011-07-11     19835707
# 2             13913              529579  2011-09-13      1110304
# 3             13913              595481  2011-10-03      1216358
# 4             13913              612947  2011-10-09       490840
# ...             ...                 ...         ...          ...
# 1042999    53622933  510698532655225551  2021-12-05     47886779
# 1043000    53629457  509962566515134799  2021-12-04    322726852
# 1043001    53656459  511460888308184263  2021-12-06      3765545
# 1043002    53657036  510753099078490860  2021-12-05    404879596
# 1043003    53673183  511475439826601150  2021-12-06     69009291
#
#         reviewer_name                                           comments  \
# 0             Michael  My girlfriend and I hadn't known Alina before ...
# 1             Mathias  Alina was a really good host. The flat is clea...
# 2             Kristin  Alina is an amazing host. She made me feel rig...
# 3             Camilla  Alina's place is so nice, the room is big and ...
# 4               Jorik  Nice location in Islington area, good for shor...
# ...               ...                                                ...
# 1042999       Shameel  Gregory is an absolutely amazing host! He went...
# 1043000        Stella  Those considering the aptm as a last minute bo...
# 1043001        Harsha  One of the worst places I have ever stayed... ...
# 1043002       Matthew  An exceptional little apartment for a short st...
# 1043003          Arun  This place is a true gem and needle in the hay...
#
#          comments_len  key_reviewer
# 0               149.0             0
# 1                32.0             0
# 2                68.0             0
# 3                86.0             0
# 4                17.0             0
# ...               ...           ...
# 1042999          71.0             0
# 1043000          74.0             1
# 1043001          41.0             0
# 1043002          16.0             0
# 1043003          66.0             0
#
# [968950 rows x 8 columns]

# %%
#Create new dataframe for review cleaning
reviews_cleaned = review_exp[["comments"]]
reviews_cleaned
# Out:
#                                                   comments
# 0        My girlfriend and I hadn't known Alina before ...
# 1        Alina was a really good host. The flat is clea...
# 2        Alina is an amazing host. She made me feel rig...
# 3        Alina's place is so nice, the room is big and ...
# 4        Nice location in Islington area, good for shor...
# ...                                                    ...
# 1042999  Gregory is an absolutely amazing host! He went...
# 1043000  Those considering the aptm as a last minute bo...
# 1043001  One of the worst places I have ever stayed... ...
# 1043002  An exceptional little apartment for a short st...
# 1043003  This place is a true gem and needle in the hay...
#
# [968950 rows x 1 columns]

# %%
#Remove Punctuation

def remove_punct(text):
    no_punctuation = "".join([characters for characters in text if characters not in string.punctuation])
    return no_punctuation

reviews_cleaned["no_punctuation"] = reviews_cleaned["comments"].apply(lambda x: remove_punct(x))

reviews_cleaned
# Out:
# <ipython-input-30-b8b34394fd05>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_cleaned["no_punctuation"] = reviews_cleaned["comments"].apply(lambda x: remove_punct(x))
#                                                   comments  \
# 0        My girlfriend and I hadn't known Alina before ...
# 1        Alina was a really good host. The flat is clea...
# 2        Alina is an amazing host. She made me feel rig...
# 3        Alina's place is so nice, the room is big and ...
# 4        Nice location in Islington area, good for shor...
# ...                                                    ...
# 1042999  Gregory is an absolutely amazing host! He went...
# 1043000  Those considering the aptm as a last minute bo...
# 1043001  One of the worst places I have ever stayed... ...
# 1043002  An exceptional little apartment for a short st...
# 1043003  This place is a true gem and needle in the hay...
#
#                                             no_punctuation
# 0        My girlfriend and I hadnt known Alina before w...
# 1        Alina was a really good host The flat is clean...
# 2        Alina is an amazing host She made me feel righ...
# 3        Alinas place is so nice the room is big and cl...
# 4        Nice location in Islington area good for short...
# ...                                                    ...
# 1042999  Gregory is an absolutely amazing host He went ...
# 1043000  Those considering the aptm as a last minute bo...
# 1043001  One of the worst places I have ever stayed ver...
# 1043002  An exceptional little apartment for a short st...
# 1043003  This place is a true gem and needle in the hay...
#
# [968950 rows x 2 columns]

# %%
#Tokenize

tokenizer = RegexpTokenizer(r'\w+')

reviews_cleaned["tokenized"] = reviews_cleaned["no_punctuation"].apply(lambda x: tokenizer.tokenize(x.lower()))

reviews_cleaned
# Out:
# <ipython-input-34-68cce4137857>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_cleaned["tokenized"] = reviews_cleaned["no_punctuation"].apply(lambda x: tokenizer.tokenize(x.lower()))
#                                                   comments  \
# 0        My girlfriend and I hadn't known Alina before ...
# 1        Alina was a really good host. The flat is clea...
# 2        Alina is an amazing host. She made me feel rig...
# 3        Alina's place is so nice, the room is big and ...
# 4        Nice location in Islington area, good for shor...
# ...                                                    ...
# 1042999  Gregory is an absolutely amazing host! He went...
# 1043000  Those considering the aptm as a last minute bo...
# 1043001  One of the worst places I have ever stayed... ...
# 1043002  An exceptional little apartment for a short st...
# 1043003  This place is a true gem and needle in the hay...
#
#                                             no_punctuation  \
# 0        My girlfriend and I hadnt known Alina before w...
# 1        Alina was a really good host The flat is clean...
# 2        Alina is an amazing host She made me feel righ...
# 3        Alinas place is so nice the room is big and cl...
# 4        Nice location in Islington area good for short...
# ...                                                    ...
# 1042999  Gregory is an absolutely amazing host He went ...
# 1043000  Those considering the aptm as a last minute bo...
# 1043001  One of the worst places I have ever stayed ver...
# 1043002  An exceptional little apartment for a short st...
# 1043003  This place is a true gem and needle in the hay...
#
#                                                  tokenized
# 0        [my, girlfriend, and, i, hadnt, known, alina, ...
# 1        [alina, was, a, really, good, host, the, flat,...
# 2        [alina, is, an, amazing, host, she, made, me, ...
# 3        [alinas, place, is, so, nice, the, room, is, b...
# 4        [nice, location, in, islington, area, good, fo...
# ...                                                    ...
# 1042999  [gregory, is, an, absolutely, amazing, host, h...
# 1043000  [those, considering, the, aptm, as, a, last, m...
# 1043001  [one, of, the, worst, places, i, have, ever, s...
# 1043002  [an, exceptional, little, apartment, for, a, s...
# 1043003  [this, place, is, a, true, gem, and, needle, i...
#
# [968950 rows x 3 columns]

# %%
#Remove stopwords

stopword_list = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "nor", "only", "own", "same", "so", "than", "too", "very", "can", "will", "just", "should", "now"]

def remove_stopwords(word_list):
    words = [word for word in word_list if word not in stopword_list]
    return words

reviews_cleaned["removed_stopwords"] = reviews_cleaned["tokenized"].apply(lambda x: remove_stopwords(x))

reviews_cleaned
# Out:
# <ipython-input-43-984bfa4947e6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_cleaned["removed_stopwords"] = reviews_cleaned["tokenized"].apply(lambda x: remove_stopwords(x))
#                                                   comments  \
# 0        My girlfriend and I hadn't known Alina before ...
# 1        Alina was a really good host. The flat is clea...
# 2        Alina is an amazing host. She made me feel rig...
# 3        Alina's place is so nice, the room is big and ...
# 4        Nice location in Islington area, good for shor...
# ...                                                    ...
# 1042999  Gregory is an absolutely amazing host! He went...
# 1043000  Those considering the aptm as a last minute bo...
# 1043001  One of the worst places I have ever stayed... ...
# 1043002  An exceptional little apartment for a short st...
# 1043003  This place is a true gem and needle in the hay...
#
#                                             no_punctuation  \
# 0        My girlfriend and I hadnt known Alina before w...
# 1        Alina was a really good host The flat is clean...
# 2        Alina is an amazing host She made me feel righ...
# 3        Alinas place is so nice the room is big and cl...
# 4        Nice location in Islington area good for short...
# ...                                                    ...
# 1042999  Gregory is an absolutely amazing host He went ...
# 1043000  Those considering the aptm as a last minute bo...
# 1043001  One of the worst places I have ever stayed ver...
# 1043002  An exceptional little apartment for a short st...
# 1043003  This place is a true gem and needle in the hay...
#
#                                                  tokenized  \
# 0        [my, girlfriend, and, i, hadnt, known, alina, ...
# 1        [alina, was, a, really, good, host, the, flat,...
# 2        [alina, is, an, amazing, host, she, made, me, ...
# 3        [alinas, place, is, so, nice, the, room, is, b...
# 4        [nice, location, in, islington, area, good, fo...
# ...                                                    ...
# 1042999  [gregory, is, an, absolutely, amazing, host, h...
# 1043000  [those, considering, the, aptm, as, a, last, m...
# 1043001  [one, of, the, worst, places, i, have, ever, s...
# 1043002  [an, exceptional, little, apartment, for, a, s...
# 1043003  [this, place, is, a, true, gem, and, needle, i...
#
#                                          removed_stopwords
# 0        [girlfriend, hadnt, known, alina, took, leap, ...
# 1        [alina, really, good, host, flat, clean, tidy,...
# 2        [alina, amazing, host, made, feel, right, home...
# 3        [alinas, place, nice, room, big, clean, bed, h...
# 4        [nice, location, islington, area, good, short,...
# ...                                                    ...
# 1042999  [gregory, absolutely, amazing, host, went, way...
# 1043000  [considering, aptm, last, minute, booking, pri...
# 1043001  [one, worst, places, ever, stayed, disappointe...
# 1043002  [exceptional, little, apartment, short, stay, ...
# 1043003  [place, true, gem, needle, haystack, nikita, a...
#
# [968950 rows x 4 columns]

# %%
#Lemmatize words

lemmatizer = WordNetLemmatizer()

def lemmatize_words(word_list):
    lemmatized_words = [lemmatizer.lemmatize(word) for word in word_list]
    return lemmatized_words

reviews_cleaned["lemmatized"] = reviews_cleaned["removed_stopwords"].apply(lambda x: lemmatize_words(x))

reviews_cleaned
# Out:
# <ipython-input-46-8f1a606529bc>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_cleaned["lemmatized"] = reviews_cleaned["removed_stopwords"].apply(lambda x: lemmatize_words(x))
#                                                   comments  \
# 0        My girlfriend and I hadn't known Alina before ...
# 1        Alina was a really good host. The flat is clea...
# 2        Alina is an amazing host. She made me feel rig...
# 3        Alina's place is so nice, the room is big and ...
# 4        Nice location in Islington area, good for shor...
# ...                                                    ...
# 1042999  Gregory is an absolutely amazing host! He went...
# 1043000  Those considering the aptm as a last minute bo...
# 1043001  One of the worst places I have ever stayed... ...
# 1043002  An exceptional little apartment for a short st...
# 1043003  This place is a true gem and needle in the hay...
#
#                                             no_punctuation  \
# 0        My girlfriend and I hadnt known Alina before w...
# 1        Alina was a really good host The flat is clean...
# 2        Alina is an amazing host She made me feel righ...
# 3        Alinas place is so nice the room is big and cl...
# 4        Nice location in Islington area good for short...
# ...                                                    ...
# 1042999  Gregory is an absolutely amazing host He went ...
# 1043000  Those considering the aptm as a last minute bo...
# 1043001  One of the worst places I have ever stayed ver...
# 1043002  An exceptional little apartment for a short st...
# 1043003  This place is a true gem and needle in the hay...
#
#                                                  tokenized  \
# 0        [my, girlfriend, and, i, hadnt, known, alina, ...
# 1        [alina, was, a, really, good, host, the, flat,...
# 2        [alina, is, an, amazing, host, she, made, me, ...
# 3        [alinas, place, is, so, nice, the, room, is, b...
# 4        [nice, location, in, islington, area, good, fo...
# ...                                                    ...
# 1042999  [gregory, is, an, absolutely, amazing, host, h...
# 1043000  [those, considering, the, aptm, as, a, last, m...
# 1043001  [one, of, the, worst, places, i, have, ever, s...
# 1043002  [an, exceptional, little, apartment, for, a, s...
# 1043003  [this, place, is, a, true, gem, and, needle, i...
#
#                                          removed_stopwords  \
# 0        [girlfriend, hadnt, known, alina, took, leap, ...
# 1        [alina, really, good, host, flat, clean, tidy,...
# 2        [alina, amazing, host, made, feel, right, home...
# 3        [alinas, place, nice, room, big, clean, bed, h...
# 4        [nice, location, islington, area, good, short,...
# ...                                                    ...
# 1042999  [gregory, absolutely, amazing, host, went, way...
# 1043000  [considering, aptm, last, minute, booking, pri...
# 1043001  [one, worst, places, ever, stayed, disappointe...
# 1043002  [exceptional, little, apartment, short, stay, ...
# 1043003  [place, true, gem, needle, haystack, nikita, a...
#
#                                                 lemmatized
# 0        [girlfriend, hadnt, known, alina, took, leap, ...
# 1        [alina, really, good, host, flat, clean, tidy,...
# 2        [alina, amazing, host, made, feel, right, home...
# 3        [alinas, place, nice, room, big, clean, bed, h...
# 4        [nice, location, islington, area, good, short,...
# ...                                                    ...
# 1042999  [gregory, absolutely, amazing, host, went, way...
# 1043000  [considering, aptm, last, minute, booking, pri...
# 1043001  [one, worst, place, ever, stayed, disappointed...
# 1043002  [exceptional, little, apartment, short, stay, ...
# 1043003  [place, true, gem, needle, haystack, nikita, a...
#
# [968950 rows x 5 columns]

# %%
#Join Final Cleaned Comments

reviews_cleaned["comments_cleaned"] = reviews_cleaned["lemmatized"].apply(lambda x: " ".join(x))

reviews_cleaned
# Out:
# <ipython-input-47-7e54a46486ee>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_cleaned["comments_cleaned"] = reviews_cleaned["lemmatized"].apply(lambda x: " ".join(x))
#                                                   comments  \
# 0        My girlfriend and I hadn't known Alina before ...
# 1        Alina was a really good host. The flat is clea...
# 2        Alina is an amazing host. She made me feel rig...
# 3        Alina's place is so nice, the room is big and ...
# 4        Nice location in Islington area, good for shor...
# ...                                                    ...
# 1042999  Gregory is an absolutely amazing host! He went...
# 1043000  Those considering the aptm as a last minute bo...
# 1043001  One of the worst places I have ever stayed... ...
# 1043002  An exceptional little apartment for a short st...
# 1043003  This place is a true gem and needle in the hay...
#
#                                             no_punctuation  \
# 0        My girlfriend and I hadnt known Alina before w...
# 1        Alina was a really good host The flat is clean...
# 2        Alina is an amazing host She made me feel righ...
# 3        Alinas place is so nice the room is big and cl...
# 4        Nice location in Islington area good for short...
# ...                                                    ...
# 1042999  Gregory is an absolutely amazing host He went ...
# 1043000  Those considering the aptm as a last minute bo...
# 1043001  One of the worst places I have ever stayed ver...
# 1043002  An exceptional little apartment for a short st...
# 1043003  This place is a true gem and needle in the hay...
#
#                                                  tokenized  \
# 0        [my, girlfriend, and, i, hadnt, known, alina, ...
# 1        [alina, was, a, really, good, host, the, flat,...
# 2        [alina, is, an, amazing, host, she, made, me, ...
# 3        [alinas, place, is, so, nice, the, room, is, b...
# 4        [nice, location, in, islington, area, good, fo...
# ...                                                    ...
# 1042999  [gregory, is, an, absolutely, amazing, host, h...
# 1043000  [those, considering, the, aptm, as, a, last, m...
# 1043001  [one, of, the, worst, places, i, have, ever, s...
# 1043002  [an, exceptional, little, apartment, for, a, s...
# 1043003  [this, place, is, a, true, gem, and, needle, i...
#
#                                          removed_stopwords  \
# 0        [girlfriend, hadnt, known, alina, took, leap, ...
# 1        [alina, really, good, host, flat, clean, tidy,...
# 2        [alina, amazing, host, made, feel, right, home...
# 3        [alinas, place, nice, room, big, clean, bed, h...
# 4        [nice, location, islington, area, good, short,...
# ...                                                    ...
# 1042999  [gregory, absolutely, amazing, host, went, way...
# 1043000  [considering, aptm, last, minute, booking, pri...
# 1043001  [one, worst, places, ever, stayed, disappointe...
# 1043002  [exceptional, little, apartment, short, stay, ...
# 1043003  [place, true, gem, needle, haystack, nikita, a...
#
#                                                 lemmatized  \
# 0        [girlfriend, hadnt, known, alina, took, leap, ...
# 1        [alina, really, good, host, flat, clean, tidy,...
# 2        [alina, amazing, host, made, feel, right, home...
# 3        [alinas, place, nice, room, big, clean, bed, h...
# 4        [nice, location, islington, area, good, short,...
# ...                                                    ...
# 1042999  [gregory, absolutely, amazing, host, went, way...
# 1043000  [considering, aptm, last, minute, booking, pri...
# 1043001  [one, worst, place, ever, stayed, disappointed...
# 1043002  [exceptional, little, apartment, short, stay, ...
# 1043003  [place, true, gem, needle, haystack, nikita, a...
#
#                                           comments_cleaned
# 0        girlfriend hadnt known alina took leap faith r...
# 1        alina really good host flat clean tidy really ...
# 2        alina amazing host made feel right home like h...
# 3        alinas place nice room big clean bed huge alin...
# 4        nice location islington area good short busine...
# ...                                                    ...
# 1042999  gregory absolutely amazing host went way show ...
# 1043000  considering aptm last minute booking price con...
# 1043001  one worst place ever stayed disappointed no be...
# 1043002  exceptional little apartment short stay longer...
# 1043003  place true gem needle haystack nikita absolute...
#
# [968950 rows x 6 columns]

# %%
review_exp["comments_cleaned"] = reviews_cleaned["comments_cleaned"]

review_exp
# Out:
#          listing_id                  id        date  reviewer_id  \
# 0             13913               80770  2010-08-18       177109
# 1             13913              367568  2011-07-11     19835707
# 2             13913              529579  2011-09-13      1110304
# 3             13913              595481  2011-10-03      1216358
# 4             13913              612947  2011-10-09       490840
# ...             ...                 ...         ...          ...
# 1042999    53622933  510698532655225551  2021-12-05     47886779
# 1043000    53629457  509962566515134799  2021-12-04    322726852
# 1043001    53656459  511460888308184263  2021-12-06      3765545
# 1043002    53657036  510753099078490860  2021-12-05    404879596
# 1043003    53673183  511475439826601150  2021-12-06     69009291
#
#         reviewer_name                                           comments  \
# 0             Michael  My girlfriend and I hadn't known Alina before ...
# 1             Mathias  Alina was a really good host. The flat is clea...
# 2             Kristin  Alina is an amazing host. She made me feel rig...
# 3             Camilla  Alina's place is so nice, the room is big and ...
# 4               Jorik  Nice location in Islington area, good for shor...
# ...               ...                                                ...
# 1042999       Shameel  Gregory is an absolutely amazing host! He went...
# 1043000        Stella  Those considering the aptm as a last minute bo...
# 1043001        Harsha  One of the worst places I have ever stayed... ...
# 1043002       Matthew  An exceptional little apartment for a short st...
# 1043003          Arun  This place is a true gem and needle in the hay...
#
#          comments_len  key_reviewer  \
# 0               149.0             0
# 1                32.0             0
# 2                68.0             0
# 3                86.0             0
# 4                17.0             0
# ...               ...           ...
# 1042999          71.0             0
# 1043000          74.0             1
# 1043001          41.0             0
# 1043002          16.0             0
# 1043003          66.0             0
#
#                                           comments_cleaned
# 0        girlfriend hadnt known alina took leap faith r...
# 1        alina really good host flat clean tidy really ...
# 2        alina amazing host made feel right home like h...
# 3        alinas place nice room big clean bed huge alin...
# 4        nice location islington area good short busine...
# ...                                                    ...
# 1042999  gregory absolutely amazing host went way show ...
# 1043000  considering aptm last minute booking price con...
# 1043001  one worst place ever stayed disappointed no be...
# 1043002  exceptional little apartment short stay longer...
# 1043003  place true gem needle haystack nikita absolute...
#
# [968950 rows x 9 columns]

# %%
#review_exp.to_csv("reviews_cleaned.csv", index = False)
